# %%
import chess

# %% [raw]
# def multiplication_table(number, length):
#     for x in range(1, length + 1):
#         print (str(number) + " * " + str(x) +" = " + str(x * number))
#
# def all_tables(length, num_tables):
#     for y in range(1, num_tables+1):
#         multiplication_table(y, length)
#         print("------------------")
#
# all_tables(12, 10)

# %%
board=chess.Board()

# %%
board.legal_moves
# Out:
# <LegalMoveGenerator at 0x20c26f41d30 (Nh3, Nf3, Nc3, Na3, h3, g3, f3, e3, d3, c3, b3, a3, h4, g4, f4, e4, d4, c4, b4, a4)>

# %%
print(board)
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R

# %%
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1')

# %%
board.push_san("e4"); board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq - 0 1')

# %%
board.push_san("e5"); board
# Out:
# Board('rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBNR w KQkq - 0 2')

# %%
board.push_san("Nf3"); board
# Out:
# Board('rnbqkbnr/pppp1ppp/8/4p3/4P3/5N2/PPPP1PPP/RNBQKB1R b KQkq - 1 2')

# %%
board.push_san("Nf6"); board
# Out:
# Board('rnbqkb1r/pppp1ppp/5n2/4p3/4P3/5N2/PPPP1PPP/RNBQKB1R w KQkq - 2 3')

# %%
board.push_san("Ne5"); board
# Out:
# Board('rnbqkb1r/pppp1ppp/5n2/4N3/4P3/8/PPPP1PPP/RNBQKB1R b KQkq - 0 3')

# %%
board.push_san("Nc6"); board
# Out:
# Board('r1bqkb1r/pppp1ppp/2n2n2/4N3/4P3/8/PPPP1PPP/RNBQKB1R w KQkq - 1 4')

# %%
board.push_san("Nc6"); board
# Out:
# Board('r1bqkb1r/pppp1ppp/2N2n2/8/4P3/8/PPPP1PPP/RNBQKB1R b KQkq - 0 4')

# %%
board.push_san("d7c6"); board
# Out:
# Board('r1bqkb1r/ppp2ppp/2p2n2/8/4P3/8/PPPP1PPP/RNBQKB1R w KQkq - 0 5')

# %%
board.push_san("d3"); board
# Out:
# Board('r1bqkb1r/ppp2ppp/2p2n2/8/4P3/3P4/PPP2PPP/RNBQKB1R b KQkq - 0 5')

# %%
board.push_san("Bc5"); board
# Out:
# Board('r1bqk2r/ppp2ppp/2p2n2/2b5/4P3/3P4/PPP2PPP/RNBQKB1R w KQkq - 1 6')

# %%
board.push_san("Bg5"); board
# Out:
# Board('r1bqk2r/ppp2ppp/2p2n2/2b3B1/4P3/3P4/PPP2PPP/RN1QKB1R b KQkq - 2 6')

# %%
board.push_san("Ne4"); board
# Out:
# Board('r1bqk2r/ppp2ppp/2p5/2b3B1/4n3/3P4/PPP2PPP/RN1QKB1R w KQkq - 0 7')

# %%
board.push_san("Bd8"); board
# Out:
# Board('r1bBk2r/ppp2ppp/2p5/2b5/4n3/3P4/PPP2PPP/RN1QKB1R b KQkq - 0 7')

# %%
board.push_san("Bf2"); board
# Out:
# Board('r1bBk2r/ppp2ppp/2p5/8/4n3/3P4/PPP2bPP/RN1QKB1R w KQkq - 0 8')

# %%
board.push_san("Ke2"); board
# Out:
# Board('r1bBk2r/ppp2ppp/2p5/8/4n3/3P4/PPP1KbPP/RN1Q1B1R b kq - 1 8')

# %%
board.push_san("Bg4"); board
# Out:
# Board('r2Bk2r/ppp2ppp/2p5/8/4n1b1/3P4/PPP1KbPP/RN1Q1B1R w kq - 2 9')

# %%
dict_moves = {
    0: "e4",
    1: "e5",
    2: "Nf3",
    3: "nf6"
}

# %%
dict_moves[2]
# Out:
# 'Nf3'

# %%
len(dict_moves)
# Out:
# 4

# %%
board.push_san("e4")
board.push_san("e5")
board.push_san("Qh5")
board.push_san("Nc6")
board.push_san("Bc4")
board.push_san("Nf6")
board.push_san("Qxf7")
# Out:
# Move.from_uci('h5f7')

# %%
board.is_check()
# Out:
# True

# %%
board.is_checkmate()
# Out:
# True

# %%
last_move = board.pop()

# %%
last_move
# Out:
# Move.from_uci('h5f7')

# %%
board
# Out:
# Board('r1bqkb1r/pppp1ppp/2n2n2/4p2Q/2B1P3/8/PPPP1PPP/RNB1K1NR w KQkq - 4 4')

# %%
board.push_san("h5f7")
# Out:
# Move.from_uci('h5f7')

# %%
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1')

# %%
board.push_san('e4')
# Out:
# Move.from_uci('e2e4')

# %%
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq - 0 1')

# %%
from chessboard import display
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
board = chess.Board()

move_list = [
    'e4', 'e5',
    'Qh5', 'Nc6',
    'Bc4', 'Nf6',
    'Qxf7'
]

display.start(board.fen())
while not board.checkForQuit():
    if move_list:
        board.push_san(move_list.pop(0))
        display.update(board.fen())
    sleep(1)
display.terminate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22992/94162842.py in <module>
#       9
#      10 display.start(board.fen())
# ---> 11 while not display.checkForQuit():
#      12     if move_list:
#      13         board.push_san(move_list.pop(0))
#
# AttributeError: module 'chessboard.display' has no attribute 'checkForQuit'

# %%
import chess.svg
chess.svg.board(board, lastmove=, size=350)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22992/2803158972.py in <module>
#       1 import chess.svg
# ----> 2 chess.svg.board(board, lastmove=True, size=350)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\chess\svg.py in board(board, orientation, lastmove, check, arrows, fill, squares, size, coordinates, colors, flipped, style)
#     349
#     350         cls = ["square", "light" if chess.BB_LIGHT_SQUARES & bb else "dark"]
# --> 351         if lastmove and square in [lastmove.from_square, lastmove.to_square]:
#     352             cls.append("lastmove")
#     353         square_color, square_opacity = _select_color(colors, " ".join(cls))
#
# AttributeError: 'bool' object has no attribute 'from_square'

# %%
board.push_san('Qxf7')
# Out:
# Move.from_uci('h5f7')

# %%
chess.Move
# Out:
# chess.Move

# %%
chess.Square()
# Out:
# 0

# %%
king_square_index = board.king(chess.WHITE)

# %%
king_square_index
# Out:
# 4

# %%
chess.BLACK
# Out:
# False

# %%
chess.WHITE
# Out:
# True
